# %% [markdown]
# ## **Library**

# %%
import os
import shutil
import zipfile

import random
from shutil import move

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

from sklearn.preprocessing import LabelEncoder

from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten, GlobalMaxPool2D, AvgPool2D, GlobalAvgPool2D, BatchNormalization, Dropout

from keras.utils.vis_utils import plot_model
from PIL import Image

# %% [markdown]
# ## **Cek Data**

# %%
#tanpa preprocessing
base_dataset = 'D:/Rifal/Dataset/Raw/CRC/'

# preprocessing
# base_dataset = 'D:/Rifal/Dataset/Preprocessing/CRC/'

msi = base_dataset+'MSIMUT'
mss = base_dataset+'MSS'

trainMSI = os.listdir(msi)
trainMSS = os.listdir(mss)
print("Total Data Train MSI   :",len(trainMSI))
print("Total Data Train MSS   :",len(trainMSS))

print("\n")

print("Nama File MSI          :",trainMSI[:1])
print("Nama File MSS          :",trainMSS[:1])
# Out:
# Total Data Train MSI   : 46704
# Total Data Train MSS   : 46704
#
#
# Nama File MSI          : ['blk-AAADECQEWVSD-TCGA-CM-4746-01Z-00-DX1.png']
# Nama File MSS          : ['blk-TGINPMKGNHYS-TCGA-CK-5912-01Z-00-DX1.png']

# %% [markdown]
# ## **Split Data**

# %%
# !pip install split-folders
# import splitfolders

# splitfolders.ratio('D:/Rifal/Dataset/Preprocessing/CRC/', output='D:/Rifal/Preprocessing/CRC/',
#                    seed=1308, ratio=(.8, .2), group_prefix=None)

# %% [markdown]
# ## **Cek Data**

# %%
# tanpa preprocessing
base_dataset = 'D:/Rifal/Dataset/CRC/'

#preprocessing
# base_dataset = 'D:/Rifal/Preprocessing/CRC/'

train_dir = base_dataset+'train'
# test_dir = base_dataset+'test'
val_dir = base_dataset+'val'

# %%
trainMSI = os.listdir(train_dir+"/MSIMUT")
trainMSS = os.listdir(train_dir+"/MSS")
print("Total Data Train MSI   : ",len(trainMSI))
print("Total Data Train MSS   : ",len(trainMSS))

print("")
valMSI = os.listdir(val_dir+"/MSIMUT")
valMSS = os.listdir(val_dir+"/MSS")
print("Total Data Val MSI   : ",len(valMSI))
print("Total Data Val MSS   : ",len(valMSS))

train_length = len(trainMSI) + len(trainMSS)
val_length = len(valMSI) + len(valMSS)

# print("")
# testMSI = os.listdir(test_dir+"/MSIMUT")
# testMSS = os.listdir(test_dir+"/MSS")
# print("Total Data Test MSI   : ",len(testMSI))
# print("Total Data Test MSS   : ",len(testMSS))
# Out:
# Total Data Train MSI   :  37363
# Total Data Train MSS   :  37363
#
# Total Data Val MSI   :  9341
# Total Data Val MSS   :  9341

# %% [markdown]
# ## **Preprocessing Data**

# %%
train_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 180,
                    horizontal_flip = True,
                    vertical_flip = True,
                    zoom_range = 0.1,
                    width_shift_range = 0.1,
                    height_shift_range = 0.1,
                    fill_mode = 'reflect')

val_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 180,
                    horizontal_flip = True,
                    vertical_flip = True,
                    zoom_range = 0.1,
                    width_shift_range = 0.1,
                    height_shift_range = 0.1,
                    fill_mode = 'reflect')

# %%
batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = (224, 224),
        batch_size = batch_size,
        class_mode = 'binary')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size = (224, 224),
        batch_size = batch_size,
#         shuffle=False,
        class_mode = 'binary')
# Out:
# Found 74726 images belonging to 2 classes.
# Found 18682 images belonging to 2 classes.

# %% [markdown]
# ## Skenario 2 Model VGG19 Lite + Augmentasi

# %%
import tensorflow as tf

# %%
# Model Scenario Kedua
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(224, 224, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(128, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(256, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Conv2D(256, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

model.compile(loss='binary_crossentropy',
              optimizer=tf.optimizers.SGD(lr=0.0001),
              metrics=['accuracy'])

checkpoint_filepath = '/Rifal/Model/CRC/Tanpa DAPL/100%_WDAPL.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
import time

start = time.time()
history = model.fit(
      train_generator,
      steps_per_epoch = train_length // batch_size,
      epochs=50,
      validation_data = validation_generator,
      validation_steps = val_length // batch_size + 1,
      verbose=1)
#       callbacks=[model_checkpoint_callback])
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# 2335/2335 [==============================] - 1919s 819ms/step - loss: 0.6912 - accuracy: 0.5286 - val_loss: 0.6775 - val_accuracy: 0.5879
# Epoch 2/50
# 2335/2335 [==============================] - 823s 352ms/step - loss: 0.6779 - accuracy: 0.5818 - val_loss: 0.6663 - val_accuracy: 0.6109
# Epoch 3/50
# 2335/2335 [==============================] - 886s 379ms/step - loss: 0.6686 - accuracy: 0.6038 - val_loss: 0.6569 - val_accuracy: 0.6230
# Epoch 4/50
# 2335/2335 [==============================] - 1019s 436ms/step - loss: 0.6608 - accuracy: 0.6168 - val_loss: 0.6472 - val_accuracy: 0.6332
# Epoch 5/50
# 2335/2335 [==============================] - 1153s 494ms/step - loss: 0.6525 - accuracy: 0.6246 - val_loss: 0.6384 - val_accuracy: 0.6463
# Epoch 6/50
# 2335/2335 [==============================] - 1281s 549ms/step - loss: 0.6446 - accuracy: 0.6331 - val_loss: 0.6293 - val_accuracy: 0.6500
# Epoch 7/50
# 2335/2335 [==============================] - 1443s 618ms/step - loss: 0.6366 - accuracy: 0.6394 - val_loss: 0.6232 - val_accuracy: 0.6540
# Epoch 8/50
# 2335/2335 [==============================] - 1757s 752ms/step - loss: 0.6299 - accuracy: 0.6501 - val_loss: 0.6134 - val_accuracy: 0.6648
# Epoch 9/50
# 2335/2335 [==============================] - 1720s 737ms/step - loss: 0.6202 - accuracy: 0.6560 - val_loss: 0.6072 - val_accuracy: 0.6654
# Epoch 10/50
# 2335/2335 [==============================] - 1828s 783ms/step - loss: 0.6154 - accuracy: 0.6575 - val_loss: 0.5989 - val_accuracy: 0.6754
# Epoch 11/50
# 2335/2335 [==============================] - 2029s 869ms/step - loss: 0.6079 - accuracy: 0.6653 - val_loss: 0.5937 - val_accuracy: 0.6782
# Epoch 12/50
# 2335/2335 [==============================] - 2631s 1s/step - loss: 0.6008 - accuracy: 0.6717 - val_loss: 0.5936 - val_accuracy: 0.6765
# Epoch 13/50
# 2335/2335 [==============================] - 2938s 1s/step - loss: 0.5943 - accuracy: 0.6742 - val_loss: 0.5780 - val_accuracy: 0.6890
# Epoch 14/50
# 2335/2335 [==============================] - 3277s 1s/step - loss: 0.5885 - accuracy: 0.6834 - val_loss: 0.5961 - val_accuracy: 0.6730
# Epoch 15/50
# 2335/2335 [==============================] - 3359s 1s/step - loss: 0.5801 - accuracy: 0.6886 - val_loss: 0.5678 - val_accuracy: 0.7028
# Epoch 16/50
# 2335/2335 [==============================] - 3677s 2s/step - loss: 0.5754 - accuracy: 0.6937 - val_loss: 0.5735 - val_accuracy: 0.6922
# Epoch 17/50
# 2335/2335 [==============================] - 3775s 2s/step - loss: 0.5704 - accuracy: 0.6973 - val_loss: 0.5800 - val_accuracy: 0.6921
# Epoch 18/50
# 2335/2335 [==============================] - 4026s 2s/step - loss: 0.5636 - accuracy: 0.7036 - val_loss: 0.5401 - val_accuracy: 0.7241
# Epoch 19/50
# 2335/2335 [==============================] - 4337s 2s/step - loss: 0.5544 - accuracy: 0.7121 - val_loss: 0.6090 - val_accuracy: 0.6673
# Epoch 20/50
# 2335/2335 [==============================] - 4539s 2s/step - loss: 0.5473 - accuracy: 0.7162 - val_loss: 0.5610 - val_accuracy: 0.7070
# Epoch 21/50
# 2335/2335 [==============================] - 4812s 2s/step - loss: 0.5397 - accuracy: 0.7239 - val_loss: 0.5375 - val_accuracy: 0.7233
# Epoch 22/50
# 2335/2335 [==============================] - 5340s 2s/step - loss: 0.5335 - accuracy: 0.7271 - val_loss: 0.5250 - val_accuracy: 0.7357
# Epoch 23/50
# 2335/2335 [==============================] - 5079s 2s/step - loss: 0.5290 - accuracy: 0.7321 - val_loss: 0.6967 - val_accuracy: 0.6348
# Epoch 24/50
# 2335/2335 [==============================] - 4606s 2s/step - loss: 0.5220 - accuracy: 0.7359 - val_loss: 0.6298 - val_accuracy: 0.6824
# Epoch 25/50
# 2335/2335 [==============================] - 5025s 2s/step - loss: 0.5141 - accuracy: 0.7415 - val_loss: 0.5080 - val_accuracy: 0.7460
# Epoch 26/50
# 2335/2335 [==============================] - 5405s 2s/step - loss: 0.5113 - accuracy: 0.7417 - val_loss: 0.5616 - val_accuracy: 0.7174
# Epoch 27/50
# 2335/2335 [==============================] - 6396s 3s/step - loss: 0.5058 - accuracy: 0.7487 - val_loss: 0.5391 - val_accuracy: 0.7306
# Epoch 28/50
# 2335/2335 [==============================] - 6803s 3s/step - loss: 0.4999 - accuracy: 0.7508 - val_loss: 0.5264 - val_accuracy: 0.7389
# Epoch 29/50
# 2335/2335 [==============================] - 7408s 3s/step - loss: 0.4970 - accuracy: 0.7533 - val_loss: 0.5222 - val_accuracy: 0.7448
# Epoch 30/50
# 2335/2335 [==============================] - 7172s 3s/step - loss: 0.4904 - accuracy: 0.7584 - val_loss: 0.5122 - val_accuracy: 0.7483
# Epoch 31/50
# 2335/2335 [==============================] - 7869s 3s/step - loss: 0.4866 - accuracy: 0.7616 - val_loss: 0.6122 - val_accuracy: 0.6853
# Epoch 32/50
# 2335/2335 [==============================] - 8594s 4s/step - loss: 0.4790 - accuracy: 0.7646 - val_loss: 0.6255 - val_accuracy: 0.6747
# Epoch 33/50
# 2335/2335 [==============================] - 9479s 4s/step - loss: 0.4774 - accuracy: 0.7694 - val_loss: 0.5379 - val_accuracy: 0.7313
# Epoch 34/50
# 2335/2335 [==============================] - 10970s 5s/step - loss: 0.4777 - accuracy: 0.7681 - val_loss: 0.5462 - val_accuracy: 0.7286
# Epoch 35/50
# 2335/2335 [==============================] - 11207s 5s/step - loss: 0.4691 - accuracy: 0.7729 - val_loss: 0.4863 - val_accuracy: 0.7669
# Epoch 36/50
# 2335/2335 [==============================] - 11754s 5s/step - loss: 0.4664 - accuracy: 0.7733 - val_loss: 0.6302 - val_accuracy: 0.7011
# Epoch 37/50
# 2335/2335 [==============================] - 12885s 6s/step - loss: 0.4629 - accuracy: 0.7777 - val_loss: 0.5215 - val_accuracy: 0.7410
# Epoch 38/50
# 2335/2335 [==============================] - 13120s 6s/step - loss: 0.4620 - accuracy: 0.7772 - val_loss: 0.4907 - val_accuracy: 0.7676
# Epoch 39/50
# 2335/2335 [==============================] - 13685s 6s/step - loss: 0.4606 - accuracy: 0.7746 - val_loss: 0.7897 - val_accuracy: 0.6653
# Epoch 40/50
# 2335/2335 [==============================] - 14522s 6s/step - loss: 0.4555 - accuracy: 0.7823 - val_loss: 0.4503 - val_accuracy: 0.7978
# Epoch 41/50
# 2335/2335 [==============================] - 15620s 7s/step - loss: 0.4453 - accuracy: 0.7877 - val_loss: 0.4617 - val_accuracy: 0.7848
# Epoch 42/50
# 2335/2335 [==============================] - 16295s 7s/step - loss: 0.4453 - accuracy: 0.7866 - val_loss: 0.5134 - val_accuracy: 0.7628
# Epoch 43/50
# 2335/2335 [==============================] - 17541s 8s/step - loss: 0.4423 - accuracy: 0.7918 - val_loss: 0.7742 - val_accuracy: 0.6385
# Epoch 44/50
# 2335/2335 [==============================] - 18974s 8s/step - loss: 0.4415 - accuracy: 0.7892 - val_loss: 0.4596 - val_accuracy: 0.7871
# Epoch 45/50
# 2335/2335 [==============================] - 19033s 8s/step - loss: 0.4375 - accuracy: 0.7936 - val_loss: 0.5084 - val_accuracy: 0.7526
# Epoch 46/50
# 2335/2335 [==============================] - 20937s 9s/step - loss: 0.4315 - accuracy: 0.7968 - val_loss: 0.4574 - val_accuracy: 0.7850
# Epoch 47/50
# 2335/2335 [==============================] - 20713s 9s/step - loss: 0.4282 - accuracy: 0.7983 - val_loss: 0.5680 - val_accuracy: 0.7187
# Epoch 48/50
# 2335/2335 [==============================] - 19638s 8s/step - loss: 0.4265 - accuracy: 0.7989 - val_loss: 0.6693 - val_accuracy: 0.6998
# Epoch 49/50
# 2335/2335 [==============================] - 22346s 10s/step - loss: 0.4245 - accuracy: 0.7992 - val_loss: 0.4899 - val_accuracy: 0.7664
# Epoch 50/50
# 2335/2335 [==============================] - 23448s 10s/step - loss: 0.4243 - accuracy: 0.8025 - val_loss: 0.4824 - val_accuracy: 0.7710
# Total time:  415097.04044246674 seconds

# %% [markdown]
# ## **Evaluasi Model**

# %%
# %cd D:/Rifal/Hasil/CRC/S2
# Out:
# D:\Rifal\Model\CRC\Tanpa DAPL

# %% [markdown]
# ### **Plot Akurasi Loss**

# %%
# %matplotlib inline

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), history.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.savefig("100%_S2_LOSS.svg")
plt.show()

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 50), history.history["val_accuracy"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.savefig("100%_S2_ACC.svg")
plt.show()

# %% [markdown]
# ### **Train**

# %%
result_train = model.evaluate(train_generator, verbose=1)
print('\n', 'Hasil Akurasi Train:-', result_train[1]," Hasil Loss Train", result_train[0])
# Out:
# 2336/2336 [==============================] - 1645s 704ms/step - loss: 0.4713 - accuracy: 0.7771
#
#  Hasil Akurasi Train:- 0.7771458625793457  Hasil Loss Train 0.47131645679473877

# %% [markdown]
# ### **Validasi**

# %%
result_val = model.evaluate(validation_generator, verbose=1)
print('\n', 'Hasil Akurasi Val:-', result_val[1]," Hasil Loss Val", result_val[0])
# Out:
# 584/584 [==============================] - 320s 547ms/step - loss: 0.4810 - accuracy: 0.7714
#
#  Hasil Akurasi Val:- 0.7714377641677856  Hasil Loss Val 0.4810214936733246

# %% [markdown]
# ### **Confusion Matrix**

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true_val = validation_generator.classes
y_pred = np.round(model.predict(validation_generator),0)

print('Confusion Matrix')
print(confusion_matrix(y_true_val, y_pred))
# Out:
# Confusion Matrix
# [[8259 1082]
#  [3153 6188]]

# %% [markdown]
# ### **Classification Report**

# %%
print('Classification Report')

target_names = ['MSI', 'MSS']
print(classification_report(y_true_val, y_pred, target_names=target_names, zero_division=1))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          MSI       0.72      0.88      0.80      9341
#          MSS       0.85      0.66      0.75      9341
#
#     accuracy                           0.77     18682
#    macro avg       0.79      0.77      0.77     18682
# weighted avg       0.79      0.77      0.77     18682

# %% [markdown]
# ### **AUC**

# %%
from sklearn.metrics import  precision_recall_curve, auc, roc_curve, roc_auc_score

fpr, tpr, _ = roc_curve(y_true_val, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='#ffba93',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='#7579e7', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Skenario Model 3')
plt.legend(loc="lower right")
plt.savefig("100%_S2_AUC.svg")
plt.show()

# %%
auc_score = roc_auc_score(y_true_val, y_pred)
fpr, tpr, th = roc_curve(y_true_val, y_pred)
print('AUC Score Skenario Model 2 = ', round(auc_score, 3))
# Out:
# AUC Score Skenario Model 2 =  0.775

# %% [markdown]
# ## **Save**

# %%
# %cd D:/Rifal/Hasil/CRC/S2
# Out:
# D:\Rifal\Model\CRC\Tanpa DAPL

# %%
from keras.models import load_model

#Save
model.save('100%_S2.h5')

# %%
from keras.models import load_model
model = load_model('100%_S2.h5')
