# %% [markdown]
# ## **Library**

# %%
import os
import shutil
import zipfile

import random
from shutil import move

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

from sklearn.preprocessing import LabelEncoder

from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten, GlobalMaxPool2D, AvgPool2D, GlobalAvgPool2D, BatchNormalization, Dropout

from keras.utils.vis_utils import plot_model
from PIL import Image

# %% [markdown]
# ## **Cek Data**

# %%
#tanpa preprocessing
base_dataset = 'D:/Rifal/Dataset/Raw/CRC/'

# preprocessing
# base_dataset = 'D:/Rifal/Dataset/Preprocessing/CRC/'

msi = base_dataset+'MSIMUT'
mss = base_dataset+'MSS'

trainMSI = os.listdir(msi)
trainMSS = os.listdir(mss)
print("Total Data Train MSI   :",len(trainMSI))
print("Total Data Train MSS   :",len(trainMSS))

print("\n")

print("Nama File MSI          :",trainMSI[:1])
print("Nama File MSS          :",trainMSS[:1])
# Out:
# Total Data Train MSI   : 46704
# Total Data Train MSS   : 46704
#
#
# Nama File MSI          : ['blk-AAADECQEWVSD-TCGA-CM-4746-01Z-00-DX1.png']
# Nama File MSS          : ['blk-TGINPMKGNHYS-TCGA-CK-5912-01Z-00-DX1.png']

# %% [markdown]
# ## **Split Data**

# %%
# !pip install split-folders
# import splitfolders

# splitfolders.ratio('D:/Rifal/Dataset/Preprocessing/CRC/', output='D:/Rifal/Preprocessing/CRC/',
#                    seed=1308, ratio=(.8, .2), group_prefix=None)

# %% [markdown]
# ## **Cek Data**

# %%
# tanpa preprocessing
base_dataset = 'D:/Rifal/Dataset/CRC/'

#preprocessing
# base_dataset = 'D:/Rifal/Preprocessing/CRC/'

train_dir = base_dataset+'train'
# test_dir = base_dataset+'test'
val_dir = base_dataset+'val'

# %%
trainMSI = os.listdir(train_dir+"/MSIMUT")
trainMSS = os.listdir(train_dir+"/MSS")
print("Total Data Train MSI   : ",len(trainMSI))
print("Total Data Train MSS   : ",len(trainMSS))

print("")
valMSI = os.listdir(val_dir+"/MSIMUT")
valMSS = os.listdir(val_dir+"/MSS")
print("Total Data Val MSI   : ",len(valMSI))
print("Total Data Val MSS   : ",len(valMSS))

train_length = len(trainMSI) + len(trainMSS)
val_length = len(valMSI) + len(valMSS)

# print("")
# testMSI = os.listdir(test_dir+"/MSIMUT")
# testMSS = os.listdir(test_dir+"/MSS")
# print("Total Data Test MSI   : ",len(testMSI))
# print("Total Data Test MSS   : ",len(testMSS))
# Out:
# Total Data Train MSI   :  37363
# Total Data Train MSS   :  37363
#
# Total Data Val MSI   :  9341
# Total Data Val MSS   :  9341

# %% [markdown]
# ## **Preprocessing Data**

# %%
train_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 180,
                    horizontal_flip = True,
                    vertical_flip = True,
                    zoom_range = 0.1,
                    width_shift_range = 0.1,
                    height_shift_range = 0.1,
                    fill_mode = 'reflect')

val_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 180,
                    horizontal_flip = True,
                    vertical_flip = True,
                    zoom_range = 0.1,
                    width_shift_range = 0.1,
                    height_shift_range = 0.1,
                    fill_mode = 'reflect')

# %%
batch_size = 32

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = (224, 224),
        batch_size = batch_size,
        class_mode = 'binary')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size = (224, 224),
        batch_size = batch_size,
#         shuffle=False,
        class_mode = 'binary')
# Out:
# Found 74726 images belonging to 2 classes.
# Found 18682 images belonging to 2 classes.

# %% [markdown]
# ## Skenario 3 Model VGG19 Lite + Augmentasi + Dropout APL

# %%
import tensorflow as tf

# %%
# Model Scenario Kedua
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(224, 224, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    
    tf.keras.layers.Conv2D(128, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    
    tf.keras.layers.Conv2D(256, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    tf.keras.layers.Conv2D(256, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    tf.keras.layers.Conv2D(512, (3,3), strides=1, padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    tf.keras.layers.Dropout(0.05),
    
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

model.compile(loss='binary_crossentropy',
              optimizer=tf.optimizers.SGD(lr=0.0001),
              metrics=['accuracy'])

checkpoint_filepath = '/Rifal/Model/CRC/Augmentasi'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
import time

start = time.time()
history = model.fit(
      train_generator,
      steps_per_epoch = train_length // batch_size,
      epochs=50,
      validation_data = validation_generator,
      validation_steps = val_length // batch_size + 1,
      verbose=1,
      callbacks=[model_checkpoint_callback])
print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/50
# 2335/2335 [==============================] - 2197s 937ms/step - loss: 0.6900 - accuracy: 0.5298 - val_loss: 0.6783 - val_accuracy: 0.5813
# Epoch 2/50
# 2335/2335 [==============================] - 914s 391ms/step - loss: 0.6793 - accuracy: 0.5720 - val_loss: 0.6673 - val_accuracy: 0.6034
# Epoch 3/50
# 2335/2335 [==============================] - 1122s 480ms/step - loss: 0.6715 - accuracy: 0.5939 - val_loss: 0.6564 - val_accuracy: 0.6235
# Epoch 4/50
# 2335/2335 [==============================] - 1040s 446ms/step - loss: 0.6629 - accuracy: 0.6130 - val_loss: 0.6473 - val_accuracy: 0.6319
# Epoch 5/50
# 2335/2335 [==============================] - 1172s 502ms/step - loss: 0.6546 - accuracy: 0.6242 - val_loss: 0.6388 - val_accuracy: 0.6382
# Epoch 6/50
# 2335/2335 [==============================] - 1303s 558ms/step - loss: 0.6477 - accuracy: 0.6265 - val_loss: 0.6297 - val_accuracy: 0.6476
# Epoch 7/50
# 2335/2335 [==============================] - 1480s 634ms/step - loss: 0.6419 - accuracy: 0.6334 - val_loss: 0.6241 - val_accuracy: 0.6521
# Epoch 8/50
# 2335/2335 [==============================] - 2021s 866ms/step - loss: 0.6354 - accuracy: 0.6366 - val_loss: 0.6170 - val_accuracy: 0.6618
# Epoch 9/50
# 2335/2335 [==============================] - 2426s 1s/step - loss: 0.6281 - accuracy: 0.6468 - val_loss: 0.6129 - val_accuracy: 0.6590
# Epoch 10/50
# 2335/2335 [==============================] - 2778s 1s/step - loss: 0.6215 - accuracy: 0.6534 - val_loss: 0.6066 - val_accuracy: 0.6644
# Epoch 11/50
# 2335/2335 [==============================] - 2743s 1s/step - loss: 0.6175 - accuracy: 0.6553 - val_loss: 0.6022 - val_accuracy: 0.6703
# Epoch 12/50
# 2335/2335 [==============================] - 2607s 1s/step - loss: 0.6121 - accuracy: 0.6595 - val_loss: 0.5967 - val_accuracy: 0.6715
# Epoch 13/50
# 2335/2335 [==============================] - 2870s 1s/step - loss: 0.6092 - accuracy: 0.6613 - val_loss: 0.5922 - val_accuracy: 0.6792
# Epoch 14/50
# 2335/2335 [==============================] - 3222s 1s/step - loss: 0.5996 - accuracy: 0.6711 - val_loss: 0.5868 - val_accuracy: 0.6816
# Epoch 15/50
# 2335/2335 [==============================] - 3520s 2s/step - loss: 0.5955 - accuracy: 0.6759 - val_loss: 0.5929 - val_accuracy: 0.6780
# Epoch 16/50
# 2335/2335 [==============================] - 3861s 2s/step - loss: 0.5924 - accuracy: 0.6770 - val_loss: 0.5890 - val_accuracy: 0.6820
# Epoch 17/50
# 2335/2335 [==============================] - 4162s 2s/step - loss: 0.5911 - accuracy: 0.6771 - val_loss: 0.5716 - val_accuracy: 0.6958
# Epoch 18/50
# 2335/2335 [==============================] - 4141s 2s/step - loss: 0.5822 - accuracy: 0.6858 - val_loss: 0.5758 - val_accuracy: 0.6955
# Epoch 19/50
# 2335/2335 [==============================] - 4018s 2s/step - loss: 0.5818 - accuracy: 0.6880 - val_loss: 0.5667 - val_accuracy: 0.7013
# Epoch 20/50
# 2335/2335 [==============================] - 4605s 2s/step - loss: 0.5751 - accuracy: 0.6908 - val_loss: 0.5581 - val_accuracy: 0.7068
# Epoch 21/50
# 2335/2335 [==============================] - 4893s 2s/step - loss: 0.5695 - accuracy: 0.6978 - val_loss: 0.5502 - val_accuracy: 0.7132
# Epoch 22/50
# 2335/2335 [==============================] - 5318s 2s/step - loss: 0.5658 - accuracy: 0.7025 - val_loss: 0.5559 - val_accuracy: 0.7080
# Epoch 23/50
# 2335/2335 [==============================] - 5409s 2s/step - loss: 0.5597 - accuracy: 0.7058 - val_loss: 0.5911 - val_accuracy: 0.6900
# Epoch 24/50
# 2335/2335 [==============================] - 5753s 2s/step - loss: 0.5570 - accuracy: 0.7065 - val_loss: 0.5335 - val_accuracy: 0.7240
# Epoch 25/50
# 2335/2335 [==============================] - 5755s 2s/step - loss: 0.5557 - accuracy: 0.7079 - val_loss: 0.5257 - val_accuracy: 0.7328
# Epoch 26/50
# 2335/2335 [==============================] - 5720s 2s/step - loss: 0.5424 - accuracy: 0.7209 - val_loss: 0.6404 - val_accuracy: 0.6582
# Epoch 27/50
# 2335/2335 [==============================] - 6550s 3s/step - loss: 0.5429 - accuracy: 0.7188 - val_loss: 0.5382 - val_accuracy: 0.7237
# Epoch 28/50
# 2335/2335 [==============================] - 7349s 3s/step - loss: 0.5359 - accuracy: 0.7245 - val_loss: 0.5446 - val_accuracy: 0.7167
# Epoch 29/50
# 2335/2335 [==============================] - 10221s 4s/step - loss: 0.5319 - accuracy: 0.7294 - val_loss: 0.5156 - val_accuracy: 0.7412
# Epoch 30/50
# 2335/2335 [==============================] - 10768s 5s/step - loss: 0.5286 - accuracy: 0.7314 - val_loss: 0.5394 - val_accuracy: 0.7275
# Epoch 31/50
# 2335/2335 [==============================] - 11338s 5s/step - loss: 0.5246 - accuracy: 0.7320 - val_loss: 0.5179 - val_accuracy: 0.7432
# Epoch 32/50
# 2335/2335 [==============================] - 13002s 6s/step - loss: 0.5219 - accuracy: 0.7364 - val_loss: 0.5251 - val_accuracy: 0.7321
# Epoch 33/50
# 2335/2335 [==============================] - 15131s 6s/step - loss: 0.5155 - accuracy: 0.7400 - val_loss: 0.5552 - val_accuracy: 0.7175
# Epoch 34/50
# 2335/2335 [==============================] - 14878s 6s/step - loss: 0.5118 - accuracy: 0.7454 - val_loss: 0.5938 - val_accuracy: 0.7021
# Epoch 35/50
# 2335/2335 [==============================] - 17608s 8s/step - loss: 0.5086 - accuracy: 0.7464 - val_loss: 0.4933 - val_accuracy: 0.7589
# Epoch 36/50
# 2335/2335 [==============================] - 17430s 7s/step - loss: 0.5059 - accuracy: 0.7483 - val_loss: 0.6182 - val_accuracy: 0.6776
# Epoch 37/50
# 2335/2335 [==============================] - 16496s 7s/step - loss: 0.5022 - accuracy: 0.7523 - val_loss: 0.6013 - val_accuracy: 0.6915
# Epoch 38/50
# 2335/2335 [==============================] - 19533s 8s/step - loss: 0.4989 - accuracy: 0.7530 - val_loss: 0.4944 - val_accuracy: 0.7564
# Epoch 39/50
# 2335/2335 [==============================] - 17961s 8s/step - loss: 0.4961 - accuracy: 0.7548 - val_loss: 0.5445 - val_accuracy: 0.7286
# Epoch 40/50
# 2335/2335 [==============================] - 17057s 7s/step - loss: 0.4930 - accuracy: 0.7564 - val_loss: 0.5096 - val_accuracy: 0.7460
# Epoch 41/50
# 2335/2335 [==============================] - 16756s 7s/step - loss: 0.4926 - accuracy: 0.7563 - val_loss: 0.5140 - val_accuracy: 0.7489
# Epoch 42/50
# 2335/2335 [==============================] - 18070s 8s/step - loss: 0.4875 - accuracy: 0.7614 - val_loss: 0.5263 - val_accuracy: 0.7397
# Epoch 43/50
# 2335/2335 [==============================] - 19357s 8s/step - loss: 0.4849 - accuracy: 0.7627 - val_loss: 0.5501 - val_accuracy: 0.7353
# Epoch 44/50
# 2335/2335 [==============================] - 20782s 9s/step - loss: 0.4808 - accuracy: 0.7683 - val_loss: 0.6818 - val_accuracy: 0.6717
# Epoch 45/50
# 2335/2335 [==============================] - 19618s 8s/step - loss: 0.4772 - accuracy: 0.7692 - val_loss: 0.5323 - val_accuracy: 0.7345
# Epoch 46/50
# 2335/2335 [==============================] - 20204s 9s/step - loss: 0.4764 - accuracy: 0.7700 - val_loss: 0.5713 - val_accuracy: 0.7167
# Epoch 47/50
# 2335/2335 [==============================] - 19835s 8s/step - loss: 0.4741 - accuracy: 0.7713 - val_loss: 0.4605 - val_accuracy: 0.7773
# Epoch 48/50
# 2335/2335 [==============================] - 20423s 9s/step - loss: 0.4750 - accuracy: 0.7706 - val_loss: 0.4759 - val_accuracy: 0.7738
# Epoch 49/50
# 2335/2335 [==============================] - 21463s 9s/step - loss: 0.4672 - accuracy: 0.7744 - val_loss: 0.5067 - val_accuracy: 0.7560
# Epoch 50/50
# 2335/2335 [==============================] - 18849s 8s/step - loss: 0.4658 - accuracy: 0.7773 - val_loss: 0.4919 - val_accuracy: 0.7608
# Total time:  475741.1561765671 seconds

# %% [markdown]
# ## **Evaluasi Model**

# %%
# %cd D:/Rifal/Hasil/CRC/S3
# Out:
# D:\Rifal\Model\CRC\Augmentasi

# %% [markdown]
# ### **Plot Akurasi Loss**

# %%
# %matplotlib inline

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), history.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.savefig("100%_S3_LOSS.svg")
plt.show()

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 50), history.history["val_accuracy"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.savefig("100%_S3_ACC.svg")
plt.show()

# %% [markdown]
# ### **Train**

# %%
result_train = model.evaluate(train_generator, verbose=1)
print('\n', 'Hasil Akurasi Train:-', result_train[1]," Hasil Loss Train", result_train[0])
# Out:
# 2336/2336 [==============================] - 15500s 7s/step - loss: 0.4855 - accuracy: 0.7616
#
#  Hasil Akurasi Train:- 0.7616224884986877  Hasil Loss Train 0.4854993224143982

# %% [markdown]
# ### **Validasi**

# %%
# model.evaluate(validation_generator)
result_val = model.evaluate(validation_generator, verbose=1)
print('\n', 'Hasil Akurasi Val:-', result_val[1]," Hasil Loss Val", result_val[0])
# Out:
# 584/584 [==============================] - 176s 293ms/step - loss: 0.4897 - accuracy: 0.7625
#
#  Hasil Akurasi Val:- 0.762498676776886  Hasil Loss Val 0.4897025525569916

# %% [markdown]
# ### **Confusion Matrix**

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true_val = validation_generator.classes
y_pred = np.round(model.predict(validation_generator),0)

print('Confusion Matrix')
print(confusion_matrix(y_true_val, y_pred))
# Out:
# Confusion Matrix
# [[6462 2879]
#  [1550 7791]]

# %% [markdown]
# ### **Classification Report**

# %%
print('Classification Report')

target_names = ['MSI', 'MSS']
print(classification_report(y_true_val, y_pred, target_names=target_names, zero_division=1))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          MSI       0.81      0.69      0.74      9341
#          MSS       0.73      0.83      0.78      9341
#
#     accuracy                           0.76     18682
#    macro avg       0.77      0.76      0.76     18682
# weighted avg       0.77      0.76      0.76     18682

# %% [markdown]
# ### **AUC**

# %%
from sklearn.metrics import  precision_recall_curve, auc, roc_curve, roc_auc_score

fpr, tpr, _ = roc_curve(y_true_val, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='#ffba93',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='#7579e7', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Skenario Model 3')
plt.legend(loc="lower right")
plt.savefig("100%_S3_AUC.svg")
plt.show()

# %%
auc_score = roc_auc_score(y_true_val, y_pred)
fpr, tpr, th = roc_curve(y_true_val, y_pred)
print('AUC Score Skenario Model 2 = ', round(auc_score, 3))
# Out:
# AUC Score Skenario Model 2 =  0.763

# %% [markdown]
# ## **Save**

# %%
# %cd D:/Rifal/Hasil/CRC/S3
# Out:
# D:\Rifal\Model\CRC\Augmentasi

# %%
from keras.models import load_model

#Save
model.save('100%_S3.h5')

# %%
from keras.models import load_model
model = load_model('100%_S3.h5')
